# %% [markdown]
# # Fine-Tuning a VLM
#
# This notebook demonstrates how to fine-tune the `HuggingFaceTB/SmolVLM-Instruct` model using the `SFTTrainer` from the `trl` library. The notebook cells run and will finetune the model. You can select your difficulty by trying out different datasets.
#
# <div style='background-color: lightblue; padding: 10px; border-radius: 5px; margin-bottom: 20px; color:black'>
#     <h2 style='margin: 0;color:blue'>Exercise: Fine-Tuning SmolVLM with SFTTrainer</h2>
#     <p>Take a dataset from the Hugging Face hub and finetune a model on it. </p>
#     <p><b>Difficulty Levels</b></p>
#     <p>🐢 Use the `HuggingFaceM4/ChartQA` dataset for SFT training run.</p>
#     <p>🐕 Use the fine-tuned to model generate a response, and improve upon the base example.</p>
#     <p>🦁 Try out the other datasets and show improvement.</p>
# </div>

# %%
# Install the requirements in Google Colab
# !pip install transformers datasets trl huggingface_hub

# Authenticate to Hugging Face
from huggingface_hub import login
login()

# for convenience you can create an environment variable containing your hub token as HF_TOKEN
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
# Import dependencies

import torch
import os
from transformers import AutoProcessor, AutoModelForVision2Seq, BitsAndBytesConfig
from transformers.image_utils import load_image

# %%
device = (
    "cuda"
    if torch.cuda.is_available()
    else "mps" if torch.backends.mps.is_available() else "cpu"
)

quantization_config = BitsAndBytesConfig(load_in_4bit=True, 
                                         bnb_4bit_use_double_quant=True, 
                                         bnb_4bit_quant_type="nf4", 
                                         bnb_4bit_compute_dtype=torch.bfloat16)
model_name = "HuggingFaceTB/SmolVLM-Instruct"
model = AutoModelForVision2Seq.from_pretrained(
    model_name,
    quantization_config=quantization_config,
    torch_dtype=torch.bfloat16,
).to(device)
processor = AutoProcessor.from_pretrained("HuggingFaceTB/SmolVLM-Instruct")

# Set our name for the finetune to be saved &/ uploaded to
finetune_name = "SmolVLM-FT-MyDataset"
finetune_tags = ["smol-course", "module_5"]
# Out:
# `low_cpu_mem_usage` was None, now default to True since model is quantized.
# You shouldn't move a model that is dispatched using accelerate hooks.
# Some kwargs in processor config are unused and will not have any effect: image_seq_len.

# %% [markdown]
# ## Dataset Preparation
#
# We will load a sample dataset and format it for training. The dataset should be structured with input-output pairs, where each input is a prompt and the output is the expected response from the model.
#
# **TRL will format input messages based on the model's chat templates.** They need to be represented as a list of dictionaries with the keys: `role` and `content`,.

# %%
# Load a sample dataset
from datasets import load_dataset

# TODO: define your dataset and config using the path and name parameters
dataset_name = "HuggingFaceM4/ChartQA"
ds = load_dataset(path=dataset_name)
ds
# Out:
# Using the latest cached version of the dataset since HuggingFaceM4/ChartQA couldn't be found on the Hugging Face Hub
# Found the latest cached dataset configuration 'default' at D:\huggingface\datasets\HuggingFaceM4___chart_qa\default\0.0.0\b605b6e08b57faf4359aeb2fe6a3ca595f99b6c5 (last modified on Wed Jan 22 23:18:02 2025).
# DatasetDict({
#     train: Dataset({
#         features: ['image', 'query', 'label', 'human_or_machine'],
#         num_rows: 28299
#     })
#     val: Dataset({
#         features: ['image', 'query', 'label', 'human_or_machine'],
#         num_rows: 1920
#     })
#     test: Dataset({
#         features: ['image', 'query', 'label', 'human_or_machine'],
#         num_rows: 2500
#     })
# })

# %%
import matplotlib.pyplot as plt
sample = ds['train'][3]

# Display the structure of a single sample
sample['image_size'] = sample['image'].size,

# Visualize the image and related metadata
plt.imshow(sample['image'])
plt.axis("off")
plt.title("Sample Chart Image")
plt.show()

print(sample)

# Preprocess the sample
prompt = [{"role": "user", "content": [{"type": "image"}, {"type": "text", "text": sample["query"]}]}]
formatted_query = processor.apply_chat_template(prompt, tokenize=False)

inputs = processor(
    images=sample["image"], 
    text=formatted_query, 
    return_tensors="pt"
).to(device)
inputs = {key: val.to(device, dtype=torch.bfloat16) if val.dtype == torch.float else val.to(device) for key, val in inputs.items()}

# Generate predictions
with torch.no_grad():
    outputs = model.generate(**inputs,
                             max_length=1600)

# Decode the prediction
prediction = processor.batch_decode(outputs, skip_special_tokens=True)

# Display the result
print(f"Query: {sample['query']}")
print(f"Expected Answer: {sample['label'][0]}")
print(f"Model Prediction: {prediction[0]}")
# Out:
# {'image': <PIL.PngImagePlugin.PngImageFile image mode=RGB size=314x281 at 0x25C1C74FE50>, 'query': 'What is the sum favourable  value in the year 2014 and 2015?', 'label': ['95'], 'human_or_machine': 0, 'image_size': ((314, 281),)}
# c:\Users\xxSg\anaconda3\envs\pytorch311\Lib\site-packages\transformers\integrations\sdpa_attention.py:48: UserWarning: 1Torch was not compiled with flash attention. (Triggered internally at C:\cb\pytorch_1000000000000\work\aten\src\ATen\native\transformers\cuda\sdp_utils.cpp:263.)
#   attn_output = torch.nn.functional.scaled_dot_product_attention(
# Query: What is the sum favourable  value in the year 2014 and 2015?
# Expected Answer: 95
# Model Prediction: User:What is the sum favourable  value in the year 2014 and 2015?
# Answer: 91.

# %% [markdown]
# ## Set Up LoRA

# %%
from peft import LoraConfig, get_peft_model

# Configure LoRA
peft_config = LoraConfig(
    lora_alpha=16,
    lora_dropout=0.05,
    r=8,
    bias="none",
    target_modules=["q_proj", "v_proj"],
    task_type="CAUSAL_LM",
)

# Apply PEFT model adaptation
peft_model = get_peft_model(model, peft_config)

# Print trainable parameters
peft_model.print_trainable_parameters()
# Out:
# trainable params: 2,568,192 || all params: 2,248,841,072 || trainable%: 0.1142

# %% [markdown]
# ## Configuring the Trainer
#
# The `Trainer` is configured with various parameters that control the training process. These include the number of training steps, batch size, learning rate, and evaluation strategy. Adjust these parameters based on your specific requirements and computational resources.

# %%
def collate_fn(examples):
    # System message template for the VLM
    system_message = """You are a Vision Language Model specialized in interpreting visual data from chart images.
    Your task is to analyze the provided chart image and respond to queries with concise answers, usually a single word, number, or short phrase.
    The charts include a variety of types (e.g., line charts, bar charts) and contain colors, labels, and text.
    Focus on delivering accurate, succinct answers based on the visual information. Avoid additional explanation unless absolutely necessary."""

    # Initialize lists for text and image inputs
    text_inputs = []
    image_inputs = []

    # Process all examples in one loop
    for example in examples:
        # Format the chat structure for the processor
        formatted_example = {
            "messages": [
                {
                    "role": "system",
                    "content": [{"type": "text", "text": system_message}],
                },
                {
                    "role": "user",
                    "content": [
                        {
                            "type": "image",
                        },
                        {
                            "type": "text",
                            "text": example["query"],
                        },
                    ],
                },
            ]
        }
        # Apply chat template and strip extra spaces
        text_inputs.append(processor.apply_chat_template(formatted_example["messages"], tokenize=False).strip())
        
        # Ensure images are in RGB mode
        image = example["image"]
        if image.mode != 'RGB':
            image = image.convert('RGB')
        image_inputs.append( [image] )

    # Tokenize the texts and process the images
    batch = processor(
        text=text_inputs,
        images=image_inputs,
        return_tensors="pt",
        padding=True
    )

    # Clone input IDs for labels
    labels = batch["input_ids"].clone()
    labels[labels == processor.tokenizer.pad_token_id] = -100  # Mask padding tokens in labels

    # Ensure image_token is converted to string if it is an AddedToken
    # In some processor, processor.image_token return a list for each image.
    # TODO: AutoProcessor.from_pretrained("HuggingFaceTB/SmolVLM-Instruct") only have one ?
    image_token_id = processor.tokenizer.convert_tokens_to_ids(str(processor.image_token))

    # Mask image token IDs in the labels
    labels[labels == image_token_id] = -100

    # Add labels back to the batch
    batch["labels"] = labels


    return batch

# %%
from trl import SFTConfig, SFTTrainer

# Configure the Trainer
training_args = SFTConfig(
    output_dir="sft_output",  # Directory to save the model
    num_train_epochs=3,                     # number of training epochs
    per_device_train_batch_size=1,          # batch size per device during training
    gradient_accumulation_steps=16,         # number of steps before performing a backward/update pass
    gradient_checkpointing=True,            # use gradient checkpointing to save memory
    optim="adamw_torch_fused",              # use fused adamw optimizer
    logging_steps=5,                        # log every 10 steps
    save_strategy="epoch",                  # save checkpoint every epoch
    learning_rate=2e-4,                     # learning rate, based on QLoRA paper
    bf16=True,                              # use bfloat16 precision
    tf32=True,                              # use tf32 precision
    max_grad_norm=0.3,                      # max gradient norm based on QLoRA paper
    warmup_ratio=0.03,                      # warmup ratio based on QLoRA paper
    lr_scheduler_type="constant",           # use constant learning rate scheduler
    push_to_hub=True,                       # push model to hub
    gradient_checkpointing_kwargs = {"use_reentrant": False}, # use reentrant checkpointing
    # dataloader_num_workers=16, 
    dataset_text_field="", # need a dummy field for collator
    dataset_kwargs = {"skip_prepare_dataset": True}, # important for collator
    remove_unused_columns = False                    # necessary else features except label will be removed
)
# Initialize the Trainer
trainer = SFTTrainer(
    model=model,
    args=training_args,
    train_dataset=ds["train"],
    eval_dataset=ds["test"],
    data_collator=collate_fn,
    peft_config=peft_config,
    tokenizer=processor.tokenizer,
)

# TODO: 🦁 🐕 align the SFTTrainer params with your chosen dataset. For example, if you are using the `bigcode/the-stack-smol` dataset, you will need to choose the `content` column`
# Out:
# C:\Users\xxSg\AppData\Local\Temp\ipykernel_15468\2040669422.py:27: FutureWarning: `tokenizer` is deprecated and removed starting from version 0.16.0 for `SFTTrainer.__init__`. Use `processing_class` instead.
#   trainer = SFTTrainer(

# %% [markdown]
# ## Training the Model
#
# With the trainer configured, we can now proceed to train the model. The training process will involve iterating over the dataset, computing the loss, and updating the model's parameters to minimize this loss.

# %%
# Train the model
trainer.train()

# Save the model
trainer.save_model(f"./{finetune_name}")

# Save to the huggingface hub if login (HF_TOKEN is set)
if os.getenv("HF_TOKEN"):
    trainer.push_to_hub(tags=finetune_tags)
# Out:
#     <div>
#
#       <progress value='536' max='5304' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 536/5304 17:33:53 < 156:50:05, 0.01 it/s, Epoch 0.30/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>5</td>
#       <td>1.418700</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>1.270900</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>1.130300</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.890200</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.697000</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.488000</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>0.376500</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.295700</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>0.269100</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.253300</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>0.226400</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>0.222200</td>
#     </tr>
#     <tr>
#       <td>65</td>
#       <td>0.228400</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>0.228300</td>
#     </tr>
#     <tr>
#       <td>75</td>
#       <td>0.216400</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>0.205000</td>
#     </tr>
#     <tr>
#       <td>85</td>
#       <td>0.207800</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>0.201900</td>
#     </tr>
#     <tr>
#       <td>95</td>
#       <td>0.201600</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.205900</td>
#     </tr>
#     <tr>
#       <td>105</td>
#       <td>0.171700</td>
#     </tr>
#     <tr>
#       <td>110</td>
#       <td>0.161100</td>
#     </tr>
#     <tr>
#       <td>115</td>
#       <td>0.155700</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>0.171900</td>
#     </tr>
#     <tr>
#       <td>125</td>
#       <td>0.139400</td>
#     </tr>
#     <tr>
#       <td>130</td>
#       <td>0.139400</td>
#     </tr>
#     <tr>
#       <td>135</td>
#       <td>0.125200</td>
#     </tr>
#     <tr>
#       <td>140</td>
#       <td>0.133500</td>
#     </tr>
#     <tr>
#       <td>145</td>
#       <td>0.119700</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>0.116300</td>
#     </tr>
#     <tr>
#       <td>155</td>
#       <td>0.109800</td>
#     </tr>
#     <tr>
#       <td>160</td>
#       <td>0.101300</td>
#     </tr>
#     <tr>
#       <td>165</td>
#       <td>0.118800</td>
#     </tr>
#     <tr>
#       <td>170</td>
#       <td>0.106500</td>
#     </tr>
#     <tr>
#       <td>175</td>
#       <td>0.104300</td>
#     </tr>
#     <tr>
#       <td>180</td>
#       <td>0.094500</td>
#     </tr>
#     <tr>
#       <td>185</td>
#       <td>0.090300</td>
#     </tr>
#     <tr>
#       <td>190</td>
#       <td>0.097900</td>
#     </tr>
#     <tr>
#       <td>195</td>
#       <td>0.105300</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.118000</td>
#     </tr>
#     <tr>
#       <td>205</td>
#       <td>0.095000</td>
#     </tr>
#     <tr>
#       <td>210</td>
#       <td>0.107000</td>
#     </tr>
#     <tr>
#       <td>215</td>
#       <td>0.100000</td>
#     </tr>
#     <tr>
#       <td>220</td>
#       <td>0.101600</td>
#     </tr>
#     <tr>
#       <td>225</td>
#       <td>0.106600</td>
#     </tr>
#     <tr>
#       <td>230</td>
#       <td>0.109700</td>
#     </tr>
#     <tr>
#       <td>235</td>
#       <td>0.109000</td>
#     </tr>
#     <tr>
#       <td>240</td>
#       <td>0.093500</td>
#     </tr>
#     <tr>
#       <td>245</td>
#       <td>0.097400</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>0.094100</td>
#     </tr>
#     <tr>
#       <td>255</td>
#       <td>0.100000</td>
#     </tr>
#     <tr>
#       <td>260</td>
#       <td>0.108300</td>
#     </tr>
#     <tr>
#       <td>265</td>
#       <td>0.094800</td>
#     </tr>
#     <tr>
#       <td>270</td>
#       <td>0.103600</td>
#     </tr>
#     <tr>
#       <td>275</td>
#       <td>0.098600</td>
#     </tr>
#     <tr>
#       <td>280</td>
#       <td>0.097900</td>
#     </tr>
#     <tr>
#       <td>285</td>
#       <td>0.103700</td>
#     </tr>
#     <tr>
#       <td>290</td>
#       <td>0.096100</td>
#     </tr>
#     <tr>
#       <td>295</td>
#       <td>0.099800</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>0.093900</td>
#     </tr>
#     <tr>
#       <td>305</td>
#       <td>0.101400</td>
#     </tr>
#     <tr>
#       <td>310</td>
#       <td>0.099900</td>
#     </tr>
#     <tr>
#       <td>315</td>
#       <td>0.103100</td>
#     </tr>
#     <tr>
#       <td>320</td>
#       <td>0.103700</td>
#     </tr>
#     <tr>
#       <td>325</td>
#       <td>0.103200</td>
#     </tr>
#     <tr>
#       <td>330</td>
#       <td>0.104100</td>
#     </tr>
#     <tr>
#       <td>335</td>
#       <td>0.095500</td>
#     </tr>
#     <tr>
#       <td>340</td>
#       <td>0.106100</td>
#     </tr>
#     <tr>
#       <td>345</td>
#       <td>0.104100</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>0.100800</td>
#     </tr>
#     <tr>
#       <td>355</td>
#       <td>0.107700</td>
#     </tr>
#     <tr>
#       <td>360</td>
#       <td>0.097900</td>
#     </tr>
#     <tr>
#       <td>365</td>
#       <td>0.103000</td>
#     </tr>
#     <tr>
#       <td>370</td>
#       <td>0.089500</td>
#     </tr>
#     <tr>
#       <td>375</td>
#       <td>0.094400</td>
#     </tr>
#     <tr>
#       <td>380</td>
#       <td>0.099800</td>
#     </tr>
#     <tr>
#       <td>385</td>
#       <td>0.085300</td>
#     </tr>
#     <tr>
#       <td>390</td>
#       <td>0.084100</td>
#     </tr>
#     <tr>
#       <td>395</td>
#       <td>0.097700</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>0.086400</td>
#     </tr>
#     <tr>
#       <td>405</td>
#       <td>0.097000</td>
#     </tr>
#     <tr>
#       <td>410</td>
#       <td>0.099400</td>
#     </tr>
#     <tr>
#       <td>415</td>
#       <td>0.097500</td>
#     </tr>
#     <tr>
#       <td>420</td>
#       <td>0.087100</td>
#     </tr>
#     <tr>
#       <td>425</td>
#       <td>0.095100</td>
#     </tr>
#     <tr>
#       <td>430</td>
#       <td>0.095200</td>
#     </tr>
#     <tr>
#       <td>435</td>
#       <td>0.090200</td>
#     </tr>
#     <tr>
#       <td>440</td>
#       <td>0.104700</td>
#     </tr>
#     <tr>
#       <td>445</td>
#       <td>0.094600</td>
#     </tr>
#     <tr>
#       <td>450</td>
#       <td>0.099900</td>
#     </tr>
#     <tr>
#       <td>455</td>
#       <td>0.100400</td>
#     </tr>
#     <tr>
#       <td>460</td>
#       <td>0.097000</td>
#     </tr>
#     <tr>
#       <td>465</td>
#       <td>0.093900</td>
#     </tr>
#     <tr>
#       <td>470</td>
#       <td>0.093200</td>
#     </tr>
#     <tr>
#       <td>475</td>
#       <td>0.094000</td>
#     </tr>
#     <tr>
#       <td>480</td>
#       <td>0.093700</td>
#     </tr>
#     <tr>
#       <td>485</td>
#       <td>0.090800</td>
#     </tr>
#     <tr>
#       <td>490</td>
#       <td>0.089200</td>
#     </tr>
#     <tr>
#       <td>495</td>
#       <td>0.104400</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>0.094300</td>
#     </tr>
#     <tr>
#       <td>505</td>
#       <td>0.107500</td>
#     </tr>
#     <tr>
#       <td>510</td>
#       <td>0.099600</td>
#     </tr>
#     <tr>
#       <td>515</td>
#       <td>0.097700</td>
#     </tr>
#     <tr>
#       <td>520</td>
#       <td>0.090600</td>
#     </tr>
#     <tr>
#       <td>525</td>
#       <td>0.094500</td>
#     </tr>
#     <tr>
#       <td>530</td>
#       <td>0.094600</td>
#     </tr>
#   </tbody>
# </table><p>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 2
#       1 # Train the model
# ----> 2 trainer.train()
#       4 # Save the model
#       5 trainer.save_model(f"./{finetune_name}")
#
# File c:\Users\xxSg\anaconda3\envs\pytorch311\Lib\site-packages\transformers\trainer.py:2175, in Trainer.train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    2172 try:
#    2173     # Disable progress bars when uploading models during checkpoints to avoid polluting stdout
#    2174     hf_hub_utils.disable_progress_bars()
# -> 2175     return inner_training_loop(
#    2176         args=args,
#    2177         resume_from_checkpoint=resume_from_checkpoint,
#    2178         trial=trial,
#    2179         ignore_keys_for_eval=ignore_keys_for_eval,
#    2180     )
#    2181 finally:
#    2182     hf_hub_utils.enable_progress_bars()
#
# File c:\Users\xxSg\anaconda3\envs\pytorch311\Lib\site-packages\transformers\trainer.py:2544, in Trainer._inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    2537 context = (
#    2538     functools.partial(self.accelerator.no_sync, model=model)
#    2539     if i != len(batch_samples) - 1
#    2540     and self.accelerator.distributed_type != DistributedType.DEEPSPEED
#    2541     else contextlib.nullcontext
#    2542 )
#    2543 with context():
# -> 2544     tr_loss_step = self.training_step(model, inputs, num_items_in_batch)
#    2546 if (
#    2547     args.logging_nan_inf_filter
#    2548     and not is_torch_xla_available()
#    2549     and (torch.isnan(tr_loss_step) or torch.isinf(tr_loss_step))
#    2550 ):
#    2551     # if loss is nan or inf simply add the average of previous logged losses
#    2552     tr_loss = tr_loss + tr_loss / (1 + self.state.global_step - self._globalstep_last_logged)
#
# File c:\Users\xxSg\anaconda3\envs\pytorch311\Lib\site-packages\transformers\trainer.py:3688, in Trainer.training_step(self, model, inputs, num_items_in_batch)
#    3685     return loss_mb.reduce_mean().detach().to(self.args.device)
#    3687 with self.compute_loss_context_manager():
# -> 3688     loss = self.compute_loss(model, inputs, num_items_in_batch=num_items_in_batch)
#    3690 del inputs
#    3691 if (
#    3692     self.args.torch_empty_cache_steps is not None
#    3693     and self.state.global_step % self.args.torch_empty_cache_steps == 0
#    3694 ):
#
# File c:\Users\xxSg\anaconda3\envs\pytorch311\Lib\site-packages\transformers\trainer.py:3744, in Trainer.compute_loss(self, model, inputs, return_outputs, num_items_in_batch)
#    3742         loss_kwargs["num_items_in_batch"] = num_items_in_batch
#    3743     inputs = {**inputs, **loss_kwargs}
# -> 3744 outputs = model(**inputs)
#    3745 # Save past state if it exists
#    3746 # TODO: this needs to be fixed and made cleaner later.
#    3747 if self.args.past_index >= 0:
#
# File c:\Users\xxSg\anaconda3\envs\pytorch311\Lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File c:\Users\xxSg\anaconda3\envs\pytorch311\Lib\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File c:\Users\xxSg\anaconda3\envs\pytorch311\Lib\site-packages\accelerate\utils\operations.py:820, in convert_outputs_to_fp32.<locals>.forward(*args, **kwargs)
#     819 def forward(*args, **kwargs):
# --> 820     return model_forward(*args, **kwargs)
#
# File c:\Users\xxSg\anaconda3\envs\pytorch311\Lib\site-packages\accelerate\utils\operations.py:808, in ConvertOutputsToFp32.__call__(self, *args, **kwargs)
#     807 def __call__(self, *args, **kwargs):
# --> 808     return convert_to_fp32(self.model_forward(*args, **kwargs))
#
# File c:\Users\xxSg\anaconda3\envs\pytorch311\Lib\site-packages\torch\amp\autocast_mode.py:16, in autocast_decorator.<locals>.decorate_autocast(*args, **kwargs)
#      13 @functools.wraps(func)
#      14 def decorate_autocast(*args, **kwargs):
#      15     with autocast_instance:
# ---> 16         return func(*args, **kwargs)
#
# File c:\Users\xxSg\anaconda3\envs\pytorch311\Lib\site-packages\accelerate\utils\operations.py:820, in convert_outputs_to_fp32.<locals>.forward(*args, **kwargs)
#     819 def forward(*args, **kwargs):
# --> 820     return model_forward(*args, **kwargs)
#
# File c:\Users\xxSg\anaconda3\envs\pytorch311\Lib\site-packages\accelerate\utils\operations.py:808, in ConvertOutputsToFp32.__call__(self, *args, **kwargs)
#     807 def __call__(self, *args, **kwargs):
# --> 808     return convert_to_fp32(self.model_forward(*args, **kwargs))
#
# File c:\Users\xxSg\anaconda3\envs\pytorch311\Lib\site-packages\torch\amp\autocast_mode.py:16, in autocast_decorator.<locals>.decorate_autocast(*args, **kwargs)
#      13 @functools.wraps(func)
#      14 def decorate_autocast(*args, **kwargs):
#      15     with autocast_instance:
# ---> 16         return func(*args, **kwargs)
#
# File c:\Users\xxSg\anaconda3\envs\pytorch311\Lib\site-packages\peft\peft_model.py:1699, in PeftModelForCausalLM.forward(self, input_ids, attention_mask, inputs_embeds, labels, output_attentions, output_hidden_states, return_dict, task_ids, **kwargs)
#    1697     with self._enable_peft_forward_hooks(**kwargs):
#    1698         kwargs = {k: v for k, v in kwargs.items() if k not in self.special_peft_forward_args}
# -> 1699         return self.base_model(
#    1700             input_ids=input_ids,
#    1701             attention_mask=attention_mask,
#    1702             inputs_embeds=inputs_embeds,
#    1703             labels=labels,
#    1704             output_attentions=output_attentions,
#    1705             output_hidden_states=output_hidden_states,
#    1706             return_dict=return_dict,
#    1707             **kwargs,
#    1708         )
#    1710 batch_size = _get_batch_size(input_ids, inputs_embeds)
#    1711 if attention_mask is not None:
#    1712     # concat prompt attention mask
#
# File c:\Users\xxSg\anaconda3\envs\pytorch311\Lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File c:\Users\xxSg\anaconda3\envs\pytorch311\Lib\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File c:\Users\xxSg\anaconda3\envs\pytorch311\Lib\site-packages\peft\tuners\tuners_utils.py:197, in BaseTuner.forward(self, *args, **kwargs)
#     196 def forward(self, *args: Any, **kwargs: Any):
# --> 197     return self.model.forward(*args, **kwargs)
#
# File c:\Users\xxSg\anaconda3\envs\pytorch311\Lib\site-packages\accelerate\hooks.py:170, in add_hook_to_module.<locals>.new_forward(module, *args, **kwargs)
#     168         output = module._old_forward(*args, **kwargs)
#     169 else:
# --> 170     output = module._old_forward(*args, **kwargs)
#     171 return module._hf_hook.post_forward(module, output)
#
# File c:\Users\xxSg\anaconda3\envs\pytorch311\Lib\site-packages\transformers\models\idefics3\modeling_idefics3.py:1184, in Idefics3ForConditionalGeneration.forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, pixel_values, pixel_attention_mask, image_hidden_states, labels, use_cache, output_attentions, output_hidden_states, return_dict)
#    1181 return_dict = return_dict if return_dict is not None else self.config.use_return_dict
#    1183 # decoder outputs consists of (dec_features, layer_state, dec_hidden, dec_attn)
# -> 1184 outputs = self.model(
#    1185     input_ids=input_ids,
#    1186     attention_mask=attention_mask,
#    1187     position_ids=position_ids,
#    1188     past_key_values=past_key_values,
#    1189     inputs_embeds=inputs_embeds,
#    1190     pixel_values=pixel_values,
#    1191     pixel_attention_mask=pixel_attention_mask,
#    1192     image_hidden_states=image_hidden_states,
#    1193     use_cache=use_cache,
#    1194     output_attentions=output_attentions,
#    1195     output_hidden_states=output_hidden_states,
#    1196     return_dict=return_dict,
#    1197 )
#    1199 hidden_states = outputs[0]
#    1200 logits = self.lm_head(hidden_states)
#
# File c:\Users\xxSg\anaconda3\envs\pytorch311\Lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File c:\Users\xxSg\anaconda3\envs\pytorch311\Lib\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File c:\Users\xxSg\anaconda3\envs\pytorch311\Lib\site-packages\accelerate\hooks.py:170, in add_hook_to_module.<locals>.new_forward(module, *args, **kwargs)
#     168         output = module._old_forward(*args, **kwargs)
#     169 else:
# --> 170     output = module._old_forward(*args, **kwargs)
#     171 return module._hf_hook.post_forward(module, output)
#
# File c:\Users\xxSg\anaconda3\envs\pytorch311\Lib\site-packages\transformers\models\idefics3\modeling_idefics3.py:999, in Idefics3Model.forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, pixel_values, pixel_attention_mask, image_hidden_states, use_cache, output_attentions, output_hidden_states, return_dict)
#     996 patch_attention_mask = (patches_subgrid.sum(dim=(-1, -2)) > 0).bool()
#     998 # Get sequence from the vision encoder
# --> 999 image_hidden_states = self.vision_model(
#    1000     pixel_values=pixel_values,
#    1001     patch_attention_mask=patch_attention_mask,
#    1002 ).last_hidden_state
#    1004 # Modality projection & resampling
#    1005 image_hidden_states = self.connector(image_hidden_states)
#
# File c:\Users\xxSg\anaconda3\envs\pytorch311\Lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File c:\Users\xxSg\anaconda3\envs\pytorch311\Lib\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File c:\Users\xxSg\anaconda3\envs\pytorch311\Lib\site-packages\accelerate\hooks.py:170, in add_hook_to_module.<locals>.new_forward(module, *args, **kwargs)
#     168         output = module._old_forward(*args, **kwargs)
#     169 else:
# --> 170     output = module._old_forward(*args, **kwargs)
#     171 return module._hf_hook.post_forward(module, output)
#
# File c:\Users\xxSg\anaconda3\envs\pytorch311\Lib\site-packages\transformers\models\idefics3\modeling_idefics3.py:727, in Idefics3VisionTransformer.forward(self, pixel_values, patch_attention_mask, output_attentions, output_hidden_states, return_dict)
#     724 elif not self._use_flash_attention_2:
#     725     patch_attention_mask = _prepare_4d_attention_mask(patch_attention_mask, hidden_states.dtype)
# --> 727 encoder_outputs = self.encoder(
#     728     inputs_embeds=hidden_states,
#     729     attention_mask=patch_attention_mask,
#     730     output_attentions=output_attentions,
#     731     output_hidden_states=output_hidden_states,
#     732     return_dict=return_dict,
#     733 )
#     735 last_hidden_state = encoder_outputs[0]
#     736 last_hidden_state = self.post_layernorm(last_hidden_state)
#
# File c:\Users\xxSg\anaconda3\envs\pytorch311\Lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File c:\Users\xxSg\anaconda3\envs\pytorch311\Lib\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File c:\Users\xxSg\anaconda3\envs\pytorch311\Lib\site-packages\accelerate\hooks.py:170, in add_hook_to_module.<locals>.new_forward(module, *args, **kwargs)
#     168         output = module._old_forward(*args, **kwargs)
#     169 else:
# --> 170     output = module._old_forward(*args, **kwargs)
#     171 return module._hf_hook.post_forward(module, output)
#
# File c:\Users\xxSg\anaconda3\envs\pytorch311\Lib\site-packages\transformers\models\idefics3\modeling_idefics3.py:510, in Idefics3Encoder.forward(self, inputs_embeds, attention_mask, output_attentions, output_hidden_states, return_dict)
#     508     encoder_states = encoder_states + (hidden_states,)
#     509 if self.gradient_checkpointing and self.training:
# --> 510     layer_outputs = self._gradient_checkpointing_func(
#     511         encoder_layer.__call__,
#     512         hidden_states,
#     513         attention_mask,
#     514         output_attentions,
#     515     )
#     516 else:
#     517     layer_outputs = encoder_layer(
#     518         hidden_states,
#     519         attention_mask,
#     520         output_attentions=output_attentions,
#     521     )
#
# File c:\Users\xxSg\anaconda3\envs\pytorch311\Lib\site-packages\torch\_compile.py:24, in _disable_dynamo.<locals>.inner(*args, **kwargs)
#      20 @functools.wraps(fn)
#      21 def inner(*args, **kwargs):
#      22     import torch._dynamo
# ---> 24     return torch._dynamo.disable(fn, recursive)(*args, **kwargs)
#
# File c:\Users\xxSg\anaconda3\envs\pytorch311\Lib\site-packages\torch\_dynamo\eval_frame.py:489, in _TorchDynamoContext.__call__.<locals>._fn(*args, **kwargs)
#     487     dynamo_config_ctx.__enter__()
#     488 try:
# --> 489     return fn(*args, **kwargs)
#     490 finally:
#     491     set_eval_frame(prior)
#
# File c:\Users\xxSg\anaconda3\envs\pytorch311\Lib\site-packages\torch\_dynamo\external_utils.py:17, in wrap_inline.<locals>.inner(*args, **kwargs)
#      15 @functools.wraps(fn)
#      16 def inner(*args, **kwargs):
# ---> 17     return fn(*args, **kwargs)
#
# File c:\Users\xxSg\anaconda3\envs\pytorch311\Lib\site-packages\torch\utils\checkpoint.py:489, in checkpoint(function, use_reentrant, context_fn, determinism_check, debug, *args, **kwargs)
#     487 # Runs pre-forward logic
#     488 next(gen)
# --> 489 ret = function(*args, **kwargs)
#     490 # Runs post-forward logic
#     491 try:
#
# File c:\Users\xxSg\anaconda3\envs\pytorch311\Lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File c:\Users\xxSg\anaconda3\envs\pytorch311\Lib\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File c:\Users\xxSg\anaconda3\envs\pytorch311\Lib\site-packages\accelerate\hooks.py:170, in add_hook_to_module.<locals>.new_forward(module, *args, **kwargs)
#     168         output = module._old_forward(*args, **kwargs)
#     169 else:
# --> 170     output = module._old_forward(*args, **kwargs)
#     171 return module._hf_hook.post_forward(module, output)
#
# File c:\Users\xxSg\anaconda3\envs\pytorch311\Lib\site-packages\transformers\models\idefics3\modeling_idefics3.py:429, in Idefics3EncoderLayer.forward(self, hidden_states, attention_mask, output_attentions)
#     426 residual = hidden_states
#     428 hidden_states = self.layer_norm1(hidden_states)
# --> 429 hidden_states, attn_weights = self.self_attn(
#     430     hidden_states=hidden_states,
#     431     attention_mask=attention_mask,
#     432     output_attentions=output_attentions,
#     433 )
#     434 hidden_states = residual + hidden_states
#     436 residual = hidden_states
#
# File c:\Users\xxSg\anaconda3\envs\pytorch311\Lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File c:\Users\xxSg\anaconda3\envs\pytorch311\Lib\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File c:\Users\xxSg\anaconda3\envs\pytorch311\Lib\site-packages\accelerate\hooks.py:170, in add_hook_to_module.<locals>.new_forward(module, *args, **kwargs)
#     168         output = module._old_forward(*args, **kwargs)
#     169 else:
# --> 170     output = module._old_forward(*args, **kwargs)
#     171 return module._hf_hook.post_forward(module, output)
#
# File c:\Users\xxSg\anaconda3\envs\pytorch311\Lib\site-packages\transformers\models\idefics3\modeling_idefics3.py:263, in Idefics3VisionAttention.forward(self, hidden_states, attention_mask, output_attentions)
#     260 attn_output = attn_output.transpose(1, 2).contiguous()
#     261 attn_output = attn_output.reshape(batch_size, q_len, self.embed_dim)
# --> 263 attn_output = self.out_proj(attn_output)
#     265 return attn_output, attn_weights
#
# File c:\Users\xxSg\anaconda3\envs\pytorch311\Lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File c:\Users\xxSg\anaconda3\envs\pytorch311\Lib\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File c:\Users\xxSg\anaconda3\envs\pytorch311\Lib\site-packages\accelerate\hooks.py:170, in add_hook_to_module.<locals>.new_forward(module, *args, **kwargs)
#     168         output = module._old_forward(*args, **kwargs)
#     169 else:
# --> 170     output = module._old_forward(*args, **kwargs)
#     171 return module._hf_hook.post_forward(module, output)
#
# File c:\Users\xxSg\anaconda3\envs\pytorch311\Lib\site-packages\bitsandbytes\nn\modules.py:477, in Linear4bit.forward(self, x)
#     474     x = x.to(self.compute_dtype)
#     476 bias = None if self.bias is None else self.bias.to(self.compute_dtype)
# --> 477 out = bnb.matmul_4bit(x, self.weight.t(), bias=bias, quant_state=self.weight.quant_state)
#     479 out = out.to(inp_dtype)
#     481 return out
#
# File c:\Users\xxSg\anaconda3\envs\pytorch311\Lib\site-packages\bitsandbytes\autograd\_functions.py:579, in matmul_4bit(A, B, quant_state, out, bias)
#     577         return out
#     578 else:
# --> 579     return MatMul4Bit.apply(A, B, out, bias, quant_state)
#
# File c:\Users\xxSg\anaconda3\envs\pytorch311\Lib\site-packages\torch\autograd\function.py:553, in Function.apply(cls, *args, **kwargs)
#     550 if not torch._C._are_functorch_transforms_active():
#     551     # See NOTE: [functorch vjp and autograd interaction]
#     552     args = _functorch.utils.unwrap_dead_wrappers(args)
# --> 553     return super().apply(*args, **kwargs)  # type: ignore[misc]
#     555 if not is_setup_ctx_defined:
#     556     raise RuntimeError(
#     557         "In order to use an autograd.Function with functorch transforms "
#     558         "(vmap, grad, jvp, jacrev, ...), it must override the setup_context "
#     559         "staticmethod. For more details, please see "
#     560         "https://pytorch.org/docs/master/notes/extending.func.html"
#     561     )
#
# File c:\Users\xxSg\anaconda3\envs\pytorch311\Lib\site-packages\bitsandbytes\autograd\_functions.py:509, in MatMul4Bit.forward(ctx, A, B, out, bias, quant_state)
#     505         return torch.empty(A.shape[:-1] + B_shape[:1], dtype=A.dtype, device=A.device)
#     507 # 1. Dequantize
#     508 # 2. MatmulnN
# --> 509 output = torch.nn.functional.linear(A, F.dequantize_4bit(B, quant_state).to(A.dtype).t(), bias)
#     511 # 3. Save state
#     512 ctx.state = quant_state
#
# File c:\Users\xxSg\anaconda3\envs\pytorch311\Lib\site-packages\bitsandbytes\functional.py:1347, in dequantize_4bit(A, quant_state, absmax, out, blocksize, quant_type)
#    1344     absmax = quant_state.absmax
#    1346 if quant_state.nested:
# -> 1347     absmax = dequantize_blockwise(quant_state.absmax, quant_state.state2)
#    1348     absmax += quant_state.offset
#    1349     if absmax.dtype != torch.float32:
#
# File c:\Users\xxSg\anaconda3\envs\pytorch311\Lib\site-packages\bitsandbytes\functional.py:977, in dequantize_blockwise(A, quant_state, absmax, code, out, blocksize, nested)
#     975 is_on_gpu([A, absmax, out])
#     976 if out.dtype == torch.float32:
# --> 977     lib.cdequantize_blockwise_fp32(
#     978         get_ptr(quant_state.code),
#     979         get_ptr(A),
#     980         get_ptr(absmax),
#     981         get_ptr(out),
#     982         ct.c_int(quant_state.blocksize),
#     983         ct.c_int(A.numel()),
#     984     )
#     985 elif out.dtype == torch.float16:
#     986     lib.cdequantize_blockwise_fp16(
#     987         get_ptr(quant_state.code),
#     988         get_ptr(A),
#    (...)
#     992         ct.c_int(A.numel()),
#     993     )
#
# KeyboardInterrupt:

# %%
trainer.save_model(f"./{finetune_name}")
# Out:
# events.out.tfevents.1737559907.XXsg-LAPTOP.15468.0:   0%|          | 0.00/40.6k [00:00<?, ?B/s]
# Upload 3 LFS files:   0%|          | 0/3 [00:00<?, ?it/s]
# adapter_model.safetensors:   0%|          | 0.00/10.3M [00:00<?, ?B/s]
# training_args.bin:   0%|          | 0.00/5.62k [00:00<?, ?B/s]

# %%
trainer.push_to_hub(tags=finetune_tags)
# Out:
# CommitInfo(commit_url='https://huggingface.co/XXSg559/sft_output/commit/4000fca59546929251f189ff025bdc338adacc7a', commit_message='End of training', commit_description='', oid='4000fca59546929251f189ff025bdc338adacc7a', pr_url=None, repo_url=RepoUrl('https://hf-mirror.com/XXSg559/sft_output', endpoint='https://hf-mirror.com', repo_type='model', repo_id='XXSg559/sft_output'), pr_revision=None, pr_num=None)

# %% [markdown]
# ## 💐 You're done!
#
# This notebook provided a step-by-step guide to fine-tuning the `HuggingFaceTB/SmolVLM` model using the `SFTTrainer`. By following these steps, you can adapt the model to perform specific tasks more effectively. If you want to carry on working on this course, here are steps you could try out:
#
# - Try this notebook on a harder difficulty
# - Review a colleagues PR
# - Improve the course material via an Issue or PR.
